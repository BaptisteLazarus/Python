# %%
import pandas

# %%
from matplotlib import pyplot as plt
import seaborn
# %matplotlib inline

# %%
import requests

# %%
import folium

# %%
#import of stations informations and store its in a pandas dataframe
url = "https://opendata.paris.fr/api/records/1.0/search/"
dataset = "velib-disponibilite-en-temps-reel"
#get the number of stations
r = requests.get(url = url, params = dict(dataset = dataset)).json()
#get everuthing
df = pandas.DataFrame([s["fields"] for s in requests.get(url = url, params = dict(dataset = dataset, rows = r['nhits'])).json()['records']])
df.head()
# Out:
#                             name stationcode  ebike  mechanical  \
# 0  Benjamin Godard - Victor Hugo       16107      6           1
# 1      Mairie de Rosny-sous-Bois       31104      7           1
# 2             Toudouze - Clauzel        9020      4           1
# 3                Mairie du 12ème       12109      3           5
# 4    Cassini - Denfert-Rochereau       14111      3           0
#
#                            coordonnees_geo                    duedate  \
# 0                    [48.865983, 2.275725]  2023-01-11T13:29:12+00:00
# 1       [48.871256519012, 2.4865807592869]  2023-01-11T13:27:05+00:00
# 2  [48.87929591733507, 2.3373600840568547]  2023-01-11T13:29:21+00:00
# 3       [48.840855311763, 2.3875549435616]  2023-01-11T13:28:28+00:00
# 4       [48.837525839067, 2.3360354080796]  2023-01-11T13:30:16+00:00
#
#    numbikesavailable  numdocksavailable  capacity is_renting is_installed  \
# 0                  7                 28        35        OUI          OUI
# 1                  8                 20        30        OUI          OUI
# 2                  5                 16        21        OUI          OUI
# 3                  8                 22        30        OUI          OUI
# 4                  3                 21        25        OUI          OUI
#
#   nom_arrondissement_communes is_returning
# 0                       Paris          OUI
# 1             Rosny-sous-Bois          OUI
# 2                       Paris          OUI
# 3                       Paris          OUI
# 4                       Paris          OUI

# %%
#capacity distribution
seaborn.displot(data = df, x = "capacity")

# %%
#capacity distribution displayed with boxplot
seaborn.boxplot(data = df, x = "capacity")
# Out:
# <AxesSubplot:xlabel='capacity'>

# %%
#cities distribution
plt.figure(figsize=(18,18))
seaborn.boxplot(data = df, x = "capacity", y = "nom_arrondissement_communes")
# Out:
# <AxesSubplot:xlabel='capacity', ylabel='nom_arrondissement_communes'>

# %%
#Display the stations on a map
def popup(station):
    msg = "<strong>" + station["name"] + "</strong>"\
        + " (" + station["nom_arrondissement_communes"] + ")"
    return msg

centre = [48.87, 2.35]
paris = folium.Map(location = centre, zoom_start = 11))

for st in range(df.shape[0]):
    station = df.iloc[st,:]
    # print(popup(station))
    folium.Marker(station["coordonnees_geo"],
                  tooltip = station["name"],
                  popup = popup(station)).add_to(paris)
    
paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b2d49d027c0857d5b8c16c5562558d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b2d49d027c0857d5b8c16c5562558d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3b2d49d027c0857d5b8c16c5562558d9 = L.map(
#                 &quot;map_3b2d49d027c0857d5b8c16c5562558d9&quot;,
#                 {
#                     center: [48.87, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95ac101e4aabb5db1cbbb6fbaaac7a58 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b2d49d027c0857d5b8c16c5562558d9);
#
#
#             var marker_390d9f1931800b51e6f1cd71ca9b80a9 = L.marker(
#                 [48.865983, 2.275725],
#                 {}
#             ).addTo(map_3b2d49d027c0857d5b8c16c5562558d9);
#
#
#         var popup_400641437699d5ec5d2e45066a0ecdca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72dbcf6cb2697f1bbe360ba55550ac30 = $(`&lt;div id=&quot;html_72dbcf6cb2697f1bbe360ba55550ac30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Benjamin Godard - Victor Hugo&lt;/strong&gt; (Paris)&lt;/div&gt;`)[0];
#                 popup_400641437699d5ec5d2e45066a0ecdca.setContent(html_72dbcf6cb2697f1bbe360ba55550ac30);
#
#
#
#         marker_390d9f1931800b51e6f1cd71ca9b80a9.bindPopup(popup_400641437699d5ec5d2e45066a0ecdca)
#         ;
#
#
#
#
#             marker_390d9f1931800b51e6f1cd71ca9b80a9.bindTooltip(
#                 `&lt;div&gt;
#                      Benjamin Godard - Victor Hugo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_108be9425c67ca175befd1bd4b96bf95 = L.marker(
#                 [48.871256519012, 2.4865807592869],
#                 {}
#             ).addTo(map_3b2d49d027c0857d5b8c16c5562558d9);
#
#
#         var popup_cf33cf5f9ed682f5d81446b0f0efbd9a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8df0c270d84688e4b95a61cc3ea0453 = $(`&lt;div id=&quot;html_c8df0c270d84688e4b95a61cc3ea0453&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Mairie de Rosny-sous-Bois&lt;/strong&gt; (Rosny-sous-Bois)&lt;/div&gt;`)[0];
#                 popup_cf33cf5f9ed682f5d81446b0f0efbd9a.setContent(html_c8df0c270d84688e4b95a61cc3ea0453);
#
#
#
#         marker_108be9425c67ca175befd1bd4b96bf95.bindPopup(popup_cf33cf5f9ed682f5d81446b0f0efbd9a)
#         ;
#
#
#
#
#             marker_108be9425c67ca175befd1bd4b96bf95.bindTooltip(
#                 `&lt;div&gt;
#                      Mairie de Rosny-sous-Bois
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2fca9706bba0b328eb92b345fe3b9854 = L.marker(
#                 [48.87929591733507, 2.3373600840568547],
#                 {}
#             ).addTo(map_3b2d49d027c0857d5b8c16c5562558d9);
#
#
#         var popup_a09cfbe93776f852cec2505d98d2c5aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01fcd8c389e0880b9e241ce0e922c6d1 = $(`&lt;div id=&quot;html_01fcd8c389e0880b9e241ce0e922c6d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Toudouze - Clauzel&lt;/strong&gt; (Paris)&lt;/div&gt;`)[0];
#                 popup_a09cfbe93776f852cec2505d98d2c5aa.setContent(html_01fcd8c389e0880b9e241ce0e922c6d1);
#
#
#
#         marker_2fca9706bba0b328eb92b345fe3b9854.bindPopup(popup_a09cfbe93776f852cec2505d98d2c5aa)
#         ;
#
#
#
#
#             marker_2fca9706bba0b328eb92b345fe3b9854.bindTooltip(
#                 `&lt;div&gt;
#                      Toudouze - Clauzel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_693c5fa86e2b977655fe27e9c3d2370b = L.marker(
#                 [48.840855311763, 2.3875549435616],
#                 {}
#             ).addTo(map_3b2d49d027c0857d5b8c16c5562558d9);
#
#
#         var popup_d23496dfc56a99b45b5c5b425f21ba6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af76e516e086ca82d8cde50682034bdd = $(`&lt;div id=&quot;html_af76e516e086ca82d8cde50682034bdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Mairie du 12ème&lt;/strong&gt; (Paris)&lt;/div&gt;`)[0];
#                 popup_d23496dfc56a99b45b5c5b425f21ba6a.setContent(html_af76e516e086ca82d8cde50682034bdd);
#
#
#
#         marker_693c5fa86e2b977655fe27e9c3d2370b.bindPopup(popup_d23496dfc56a99b45b5c5b425f21ba6a)
#         ;
#
#
#
#
#             marker_693c5fa86e2b977655fe27e9c3d2370b.bindTooltip(
#                 `&lt;div&gt;

# %%
#stations number for each city
ag_count = df.filter(["nom_arrondissement_communes", "capacity"])\
    .groupby("nom_arrondissement_communes")\
    .count()\
    .rename(columns = {"capacity": "NumStations"})
ag_count.head()
# Out:
#                              NumStations
# nom_arrondissement_communes
# Alfortville                            5
# Arcueil                                4
# Argenteuil                             5
# Asnières-sur-Seine                    11
# Aubervilliers                         13

# %%
#capacity number for each city
ag_sum = df.filter(["nom_arrondissement_communes", "capacity", "numbikesavailable", "numdocksavailable"])\
    .groupby("nom_arrondissement_communes")\
    .aggregate(["sum"])\
    .droplevel(level = 1, axis = 1)
ag_sum.head()
# Out:
#                              capacity  numbikesavailable  numdocksavailable
# nom_arrondissement_communes
# Alfortville                       122                 53                 65
# Arcueil                           118                 13                102
# Argenteuil                        161                 83                 74
# Asnières-sur-Seine                254                101                144
# Aubervilliers                     404                163                219

# %%
#average GPS coordinates (display preparation)
ag_mean = df.filter(["nom_arrondissement_communes"])\
    .assign(lat = [c[0] for c in df["coordonnees_geo"]])\
    .assign(lng = [c[1] for c in df["coordonnees_geo"]])\
    .groupby("nom_arrondissement_communes")\
    .aggregate(["mean"])\
    .droplevel(level = 1, axis = 1)
ag_mean.head()
# Out:
#                                    lat       lng
# nom_arrondissement_communes
# Alfortville                  48.801567  2.422036
# Arcueil                      48.806420  2.331766
# Argenteuil                   48.947850  2.239504
# Asnières-sur-Seine           48.915786  2.287721
# Aubervilliers                48.910740  2.381001

# %%
#resume
ag_final = pandas.concat([ag_count, ag_sum, ag_mean], axis = 1)
ag_final.head()
# Out:
#                              NumStations  capacity  numbikesavailable  \
# nom_arrondissement_communes
# Alfortville                            5       122                 53
# Arcueil                                4       118                 13
# Argenteuil                             5       161                 83
# Asnières-sur-Seine                    11       254                101
# Aubervilliers                         13       404                163
#
#                              numdocksavailable        lat       lng
# nom_arrondissement_communes
# Alfortville                                 65  48.801567  2.422036
# Arcueil                                    102  48.806420  2.331766
# Argenteuil                                  74  48.947850  2.239504
# Asnières-sur-Seine                         144  48.915786  2.287721
# Aubervilliers                              219  48.910740  2.381001

# %%
#display markers for each city(located in stations center of the city) with belows informations
def popup_city(city):
    msg = "<strong>" + city.name + "</strong><ul>"\
        + "<li>Number of stations : " + str(city["NumStations"]) + "</li>"\
        + "<li>Total Capacity : " + str(city["capacity"]) + "</li>"\
        + "<li>Bikes Available : " + str(city["numbikesavailable"]) + "</li>"\
        + "<li>Docks Available : " + str(city["numdocksavailable"]) + "</li></ul>"
    iframe = folium.IFrame(msg)
    popup = folium.Popup(iframe,
                     min_width = 300,
                     max_width = 300)
    return popup

center = [48.87, 2.35]
map_city = folium.Map(location = center, zoom_start = 11)

for v in range(ag_final.shape[0]): #
    city = ag_final.iloc[v,:]
    folium.Marker([city.lat, city.lng],
                  tooltip = city.name,
                  popup = popup_city(city)).add_to(map_city)
map_city
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11501d727eccf7c1fd799f2f169f1809 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11501d727eccf7c1fd799f2f169f1809&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_11501d727eccf7c1fd799f2f169f1809 = L.map(
#                 &quot;map_11501d727eccf7c1fd799f2f169f1809&quot;,
#                 {
#                     center: [48.87, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7622a157363b78076c73dd92b821cedd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_11501d727eccf7c1fd799f2f169f1809);
#
#
#             var marker_ca3afcf665545e6c4465798aca10b57b = L.marker(
#                 [48.801566843457856, 2.422035698602648],
#                 {}
#             ).addTo(map_11501d727eccf7c1fd799f2f169f1809);
#
#
#         var popup_661a1e2dca5c0550f2cb6faaf0eccde1 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_aa27502c710436a0a958a3d1d89906e2 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkFsZm9ydHZpbGxlPC9zdHJvbmc+PHVsPjxsaT5OdW1iZXIgb2Ygc3RhdGlvbnMgOiA1LjA8L2xpPjxsaT5Ub3RhbCBDYXBhY2l0eSA6IDEyMi4wPC9saT48bGk+QmlrZXMgQXZhaWxhYmxlIDogNTMuMDwvbGk+PGxpPkRvY2tzIEF2YWlsYWJsZSA6IDY1LjA8L2xpPjwvdWw+&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_661a1e2dca5c0550f2cb6faaf0eccde1.setContent(i_frame_aa27502c710436a0a958a3d1d89906e2);
#
#
#
#         marker_ca3afcf665545e6c4465798aca10b57b.bindPopup(popup_661a1e2dca5c0550f2cb6faaf0eccde1)
#         ;
#
#
#
#
#             marker_ca3afcf665545e6c4465798aca10b57b.bindTooltip(
#                 `&lt;div&gt;
#                      Alfortville
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_40e9f841e4483d3550e2ea6102af2cd6 = L.marker(
#                 [48.80642003848464, 2.3317663781633295],
#                 {}
#             ).addTo(map_11501d727eccf7c1fd799f2f169f1809);
#
#
#         var popup_f057c1106d169d8017e05ec9d5c1247b = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_1e031bd039452d97d13401db4051b0e1 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkFyY3VlaWw8L3N0cm9uZz48dWw+PGxpPk51bWJlciBvZiBzdGF0aW9ucyA6IDQuMDwvbGk+PGxpPlRvdGFsIENhcGFjaXR5IDogMTE4LjA8L2xpPjxsaT5CaWtlcyBBdmFpbGFibGUgOiAxMy4wPC9saT48bGk+RG9ja3MgQXZhaWxhYmxlIDogMTAyLjA8L2xpPjwvdWw+&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_f057c1106d169d8017e05ec9d5c1247b.setContent(i_frame_1e031bd039452d97d13401db4051b0e1);
#
#
#
#         marker_40e9f841e4483d3550e2ea6102af2cd6.bindPopup(popup_f057c1106d169d8017e05ec9d5c1247b)
#         ;
#
#
#
#
#             marker_40e9f841e4483d3550e2ea6102af2cd6.bindTooltip(
#                 `&lt;div&gt;
#                      Arcueil
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ac695b4b39cb029e0ed511317535ef6a = L.marker(
#                 [48.94785041184114, 2.2395036779070296],
#                 {}
#             ).addTo(map_11501d727eccf7c1fd799f2f169f1809);
#
#
#         var popup_08cae348780ed67e046ec88f5b51285c = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_884100d4bbfcbddbd74746eefd620274 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkFyZ2VudGV1aWw8L3N0cm9uZz48dWw+PGxpPk51bWJlciBvZiBzdGF0aW9ucyA6IDUuMDwvbGk+PGxpPlRvdGFsIENhcGFjaXR5IDogMTYxLjA8L2xpPjxsaT5CaWtlcyBBdmFpbGFibGUgOiA4My4wPC9saT48bGk+RG9ja3MgQXZhaWxhYmxlIDogNzQuMDwvbGk+PC91bD4=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_08cae348780ed67e046ec88f5b51285c.setContent(i_frame_884100d4bbfcbddbd74746eefd620274);
#
#
#
#         marker_ac695b4b39cb029e0ed511317535ef6a.bindPopup(popup_08cae348780ed67e046ec88f5b51285c)
#         ;
#
#
#
#
#             marker_ac695b4b39cb029e0ed5113
