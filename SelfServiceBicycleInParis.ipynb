# %%
import pandas

# %%
from matplotlib import pyplot as plt
import seaborn
# %matplotlib inline

# %%
import requests

# %%
import folium
from IPython.core.display import display, HTML

def folium_deepnote_show(m):
    data = m.get_root().render()
    data_fixed_height = data.replace('width: 100%;height: 100%', 'width: 100%').replace('height: 100.0%;', 'height: 609px;', 1)
    display(HTML(data_fixed_height))

# %%
#import of stations informations and store its in a pandas dataframe
url = "https://opendata.paris.fr/api/records/1.0/search/"
dataset = "velib-disponibilite-en-temps-reel"
#get the number of stations
r = requests.get(url = url, params = dict(dataset = dataset)).json()
#get everuthing
df = pandas.DataFrame([s["fields"] for s in requests.get(url = url, params = dict(dataset = dataset, rows = r['nhits'])).json()['records']])
df.head()
# Out:
#                             name stationcode  ebike  mechanical  \
# 0  Benjamin Godard - Victor Hugo       16107      6           1
# 1      Mairie de Rosny-sous-Bois       31104      7           1
# 2             Toudouze - Clauzel        9020      4           1
# 3                Mairie du 12ème       12109      3           5
# 4    Cassini - Denfert-Rochereau       14111      3           0
#
#                            coordonnees_geo                    duedate  \
# 0                    [48.865983, 2.275725]  2023-01-11T13:29:12+00:00
# 1       [48.871256519012, 2.4865807592869]  2023-01-11T13:27:05+00:00
# 2  [48.87929591733507, 2.3373600840568547]  2023-01-11T13:29:21+00:00
# 3       [48.840855311763, 2.3875549435616]  2023-01-11T13:28:28+00:00
# 4       [48.837525839067, 2.3360354080796]  2023-01-11T13:30:16+00:00
#
#    numbikesavailable  numdocksavailable  capacity is_renting is_installed  \
# 0                  7                 28        35        OUI          OUI
# 1                  8                 20        30        OUI          OUI
# 2                  5                 16        21        OUI          OUI
# 3                  8                 22        30        OUI          OUI
# 4                  3                 21        25        OUI          OUI
#
#   nom_arrondissement_communes is_returning
# 0                       Paris          OUI
# 1             Rosny-sous-Bois          OUI
# 2                       Paris          OUI
# 3                       Paris          OUI
# 4                       Paris          OUI

# %%
#capacity distribution
seaborn.displot(data = df, x = "capacity")

# %%
#capacity distribution displayed with boxplot
seaborn.boxplot(data = df, x = "capacity")
# Out:
# <AxesSubplot:xlabel='capacity'>

# %%
#cities distribution
plt.figure(figsize=(18,18))
seaborn.boxplot(data = df, x = "capacity", y = "nom_arrondissement_communes")
# Out:
# <AxesSubplot:xlabel='capacity', ylabel='nom_arrondissement_communes'>

# %%
#Display the stations on a map
def popup(station):
    msg = "<strong>" + station["name"] + "</strong>"\
        + " (" + station["nom_arrondissement_communes"] + ")"
    return msg

centre = [48.87, 2.35]
paris = folium.Map(location = centre, zoom_start = 11)

for st in range(df.shape[0]):
    station = df.iloc[st,:]
    # print(popup(station))
    folium.Marker(station["coordonnees_geo"],
                  tooltip = station["name"],
                  popup = popup(station)).add_to(paris)
    
folium_deepnote_show(paris)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_30236af5b86572309267e3f0249b5649 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 609px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class="folium-map" id="map_30236af5b86572309267e3f0249b5649" ></div>
#
# </body>
# <script>
#
#             var map_30236af5b86572309267e3f0249b5649 = L.map(
#                 "map_30236af5b86572309267e3f0249b5649",
#                 {
#                     center: [48.87, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2790b309682caf3bad1bdb4527528839 = L.tileLayer(
#                 "https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
#                 {"attribution": "Data by \u0026copy; \u003ca href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\"http://www.openstreetmap.org/copyright\"\u003eODbL\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
#             ).addTo(map_30236af5b86572309267e3f0249b5649);
#
#
#             var marker_89da04d320c908b4a61b5420de600e7f = L.marker(
#                 [48.865983, 2.275725],
#                 {}
#             ).addTo(map_30236af5b86572309267e3f0249b5649);
#
#
#         var popup_9e0f65bbde52420196541584d4cea983 = L.popup({"maxWidth": "100%"});
#
#
#
#                 var html_ae788191a451f2d39d56740627bb429a = $(`<div id="html_ae788191a451f2d39d56740627bb429a" style="width: 100.0%; height: 100.0%;"><strong>Benjamin Godard - Victor Hugo</strong> (Paris)</div>`)[0];
#                 popup_9e0f65bbde52420196541584d4cea983.setContent(html_ae788191a451f2d39d56740627bb429a);
#
#
#
#         marker_89da04d320c908b4a61b5420de600e7f.bindPopup(popup_9e0f65bbde52420196541584d4cea983)
#         ;
#
#
#
#
#             marker_89da04d320c908b4a61b5420de600e7f.bindTooltip(
#                 `<div>
#                      Benjamin Godard - Victor Hugo
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_6c71078b48021708ec38ed5a6d76e906 = L.marker(
#                 [48.871256519012, 2.4865807592869],
#                 {}
#             ).addTo(map_30236af5b86572309267e3f0249b5649);
#
#
#         var popup_e05035ed22365c5c29d663d0faa4bce4 = L.popup({"maxWidth": "100%"});
#
#
#
#                 var html_4697099419d5678af9811e3e5e6064dc = $(`<div id="html_4697099419d5678af9811e3e5e6064dc" style="width: 100.0%; height: 100.0%;"><strong>Mairie de Rosny-sous-Bois</strong> (Rosny-sous-Bois)</div>`)[0];
#                 popup_e05035ed22365c5c29d663d0faa4bce4.setContent(html_4697099419d5678af9811e3e5e6064dc);
#
#
#
#         marker_6c71078b48021708ec38ed5a6d76e906.bindPopup(popup_e05035ed22365c5c29d663d0faa4bce4)
#         ;
#
#
#
#
#             marker_6c71078b48021708ec38ed5a6d76e906.bindTooltip(
#                 `<div>
#                      Mairie de Rosny-sous-Bois
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_0c988cd8bf3423682df06d67c1bc0e64 = L.marker(
#                 [48.87929591733507, 2.3373600840568547],
#                 {}
#             ).addTo(map_30236af5b86572309267e3f0249b5649);
#
#
#         var popup_23b0e595a4a0c202a82bbcba70d95648 = L.popup({"maxWidth": "100%"});
#
#
#
#                 var html_7d896b67ef45e37d946c59142439e275 = $(`<div id="html_7d896b67ef45e37d946c59142439e275" style="width: 100.0%; height: 100.0%;"><strong>Toudouze - Clauzel</strong> (Paris)</div>`)[0];
#                 popup_23b0e595a4a0c202a82bbcba70d95648.setContent(html_7d896b67ef45e37d946c59142439e275);
#
#
#
#         marker_0c988cd8bf3423682df06d67c1bc0e64.bindPopup(popup_23b0e595a4a0c202a82bbcba70d95648)
#         ;
#
#
#
#
#             marker_0c988cd8bf3423682df06d67c1bc0e64.bindTooltip(
#                 `<div>
#                      Toudouze - Clauzel
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_c3eb4d8572b5afb374c2c8636bfb9c97 = L.marker(
#                 [48.840855311763, 2.3875549435616],
#                 {}
#             ).addTo(map_30236af5b86572309267e3f0249b5649);
#
#
#         var popup_cc4c7e825a6e48fcba302c0d1f3d1836 = L.popup({"maxWidth": "100%"});
#
#
#
#                 var html_5ae84be08e88bc6a952450f5c5c47576 = $(`<div id="html_5ae84be08e88bc6a952450f5c5c47576" style="width: 100.0%; height: 100.0%;"><strong>Mairie du 12ème</strong> (Paris)</div>`)[0];
#                 popup_cc4c7e825a6e48fcba302c0d1f3d1836.setContent(html_5ae84be08e88bc6a952450f5c5c47576);
#
#
#
#         marker_c3eb4d8572b5afb374c2c8636bfb9c97.bindPopup(popup_cc4c7e825a6e48fcba302c0d1f3d1836)
#         ;
#
#
#
#
#             marker_c3eb4d8572b5afb374c2c8636bfb9c97.bindTooltip(
#                 `<div>
#                      Mairie du 12ème
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_d221eabf509115e6eabeb26b75e30471 = L.marker(
#                 [48.837525839067, 2.3360354080796],
#                 {}
#             ).addTo(map_30236af5b86572309267e3f0249b5649);
#
#
#         var popup_33a3a469a4d5ecfdc24881fe4835cbd2 = L.popup({"maxWidth": "100%"});
#
#
#
#                 var html_f2d5498299c47c93de365b8fc27b3e7e = $(`<div id="html_f2d5498299c47c93de365b8fc27b3e7e" style="width: 100.0%; height: 100.0%;"><strong>Cassini - Denfert-Rochereau</strong> (Paris)</div>`)[0];
#                 popup_33a3a469a4d5ecfdc24881fe4835cbd2.setContent(html_f2d5498299c47c93de365b8fc27b3e7e);
#
#
#
#         marker_d221eabf509115e6eabeb26b75e30471.bindPopup(popup_33a3a469a4d5ecfdc24881fe4835cbd2)
#         ;
#
#
#
#
#             marker_d221eabf509115e6eabeb26b75e30471.bindTooltip(
#                 `<div>
#                      Cassini - Denfert-Rochereau
#                  </div>`,
#                 {"sticky": true}

# %%
#stations number for each city
ag_count = df.filter(["nom_arrondissement_communes", "capacity"])\
    .groupby("nom_arrondissement_communes")\
    .count()\
    .rename(columns = {"capacity": "NumStations"})
ag_count.head()
# Out:
#                              NumStations
# nom_arrondissement_communes
# Alfortville                            5
# Arcueil                                4
# Argenteuil                             5
# Asnières-sur-Seine                    11
# Aubervilliers                         13

# %%
#capacity number for each city
ag_sum = df.filter(["nom_arrondissement_communes", "capacity", "numbikesavailable", "numdocksavailable"])\
    .groupby("nom_arrondissement_communes")\
    .aggregate(["sum"])\
    .droplevel(level = 1, axis = 1)
ag_sum.head()
# Out:
#                              capacity  numbikesavailable  numdocksavailable
# nom_arrondissement_communes
# Alfortville                       122                 53                 65
# Arcueil                           118                 13                102
# Argenteuil                        161                 83                 74
# Asnières-sur-Seine                254                101                144
# Aubervilliers                     404                163                219

# %%
#average GPS coordinates (display preparation)
ag_mean = df.filter(["nom_arrondissement_communes"])\
    .assign(lat = [c[0] for c in df["coordonnees_geo"]])\
    .assign(lng = [c[1] for c in df["coordonnees_geo"]])\
    .groupby("nom_arrondissement_communes")\
    .aggregate(["mean"])\
    .droplevel(level = 1, axis = 1)
ag_mean.head()
# Out:
#                                    lat       lng
# nom_arrondissement_communes
# Alfortville                  48.801567  2.422036
# Arcueil                      48.806420  2.331766
# Argenteuil                   48.947850  2.239504
# Asnières-sur-Seine           48.915786  2.287721
# Aubervilliers                48.910740  2.381001

# %%
#resume
ag_final = pandas.concat([ag_count, ag_sum, ag_mean], axis = 1)
ag_final.head()
# Out:
#                              NumStations  capacity  numbikesavailable  \
# nom_arrondissement_communes
# Alfortville                            5       122                 53
# Arcueil                                4       118                 13
# Argenteuil                             5       161                 83
# Asnières-sur-Seine                    11       254                101
# Aubervilliers                         13       404                163
#
#                              numdocksavailable        lat       lng
# nom_arrondissement_communes
# Alfortville                                 65  48.801567  2.422036
# Arcueil                                    102  48.806420  2.331766
# Argenteuil                                  74  48.947850  2.239504
# Asnières-sur-Seine                         144  48.915786  2.287721
# Aubervilliers                              219  48.910740  2.381001

# %%
#display markers for each city(located in stations center of the city) with belows informations
def popup_city(city):
    msg = "<strong>" + city.name + "</strong><ul>"\
        + "<li>Number of stations : " + str(city["NumStations"]) + "</li>"\
        + "<li>Total Capacity : " + str(city["capacity"]) + "</li>"\
        + "<li>Bikes Available : " + str(city["numbikesavailable"]) + "</li>"\
        + "<li>Docks Available : " + str(city["numdocksavailable"]) + "</li></ul>"
    iframe = folium.IFrame(msg)
    popup = folium.Popup(iframe,
                     min_width = 300,
                     max_width = 300)
    return popup

center = [48.87, 2.35]
map_city = folium.Map(location = center, zoom_start = 11)

for v in range(ag_final.shape[0]): #
    city = ag_final.iloc[v,:]
    folium.Marker([city.lat, city.lng],
                  tooltip = city.name,
                  popup = popup_city(city)).add_to(map_city)
folium_deepnote_show(map_city)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_c0e0a799fb5858581a013b45ef3d166e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 609px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class="folium-map" id="map_c0e0a799fb5858581a013b45ef3d166e" ></div>
#
# </body>
# <script>
#
#             var map_c0e0a799fb5858581a013b45ef3d166e = L.map(
#                 "map_c0e0a799fb5858581a013b45ef3d166e",
#                 {
#                     center: [48.87, 2.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ce5d22094e3704110a6524ceaf9d64d = L.tileLayer(
#                 "https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
#                 {"attribution": "Data by \u0026copy; \u003ca href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\"http://www.openstreetmap.org/copyright\"\u003eODbL\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
#             ).addTo(map_c0e0a799fb5858581a013b45ef3d166e);
#
#
#             var marker_f009a1293f145c87d97435dbc4fe9163 = L.marker(
#                 [48.801566843457856, 2.422035698602648],
#                 {}
#             ).addTo(map_c0e0a799fb5858581a013b45ef3d166e);
#
#
#         var popup_e5e3cd90f76f72a3876e05a40c13f6fb = L.popup({"maxWidth": 300, "minWidth": 300});
#
#
#
#                 var i_frame_b8d97c83c74147a2bb4f141b8bb12cea = $(`<div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkFsZm9ydHZpbGxlPC9zdHJvbmc+PHVsPjxsaT5OdW1iZXIgb2Ygc3RhdGlvbnMgOiA1LjA8L2xpPjxsaT5Ub3RhbCBDYXBhY2l0eSA6IDEyMi4wPC9saT48bGk+QmlrZXMgQXZhaWxhYmxlIDogNTMuMDwvbGk+PGxpPkRvY2tzIEF2YWlsYWJsZSA6IDY1LjA8L2xpPjwvdWw+" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;"></iframe></div></div>`)[0];
#                 popup_e5e3cd90f76f72a3876e05a40c13f6fb.setContent(i_frame_b8d97c83c74147a2bb4f141b8bb12cea);
#
#
#
#         marker_f009a1293f145c87d97435dbc4fe9163.bindPopup(popup_e5e3cd90f76f72a3876e05a40c13f6fb)
#         ;
#
#
#
#
#             marker_f009a1293f145c87d97435dbc4fe9163.bindTooltip(
#                 `<div>
#                      Alfortville
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_ad173c242366cfa4dcdfe44a704df69c = L.marker(
#                 [48.80642003848464, 2.3317663781633295],
#                 {}
#             ).addTo(map_c0e0a799fb5858581a013b45ef3d166e);
#
#
#         var popup_ee032c2c92d399e3c1dde33f769745a7 = L.popup({"maxWidth": 300, "minWidth": 300});
#
#
#
#                 var i_frame_42707cec33db05b77e9d72adcf2d9f75 = $(`<div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkFyY3VlaWw8L3N0cm9uZz48dWw+PGxpPk51bWJlciBvZiBzdGF0aW9ucyA6IDQuMDwvbGk+PGxpPlRvdGFsIENhcGFjaXR5IDogMTE4LjA8L2xpPjxsaT5CaWtlcyBBdmFpbGFibGUgOiAxMy4wPC9saT48bGk+RG9ja3MgQXZhaWxhYmxlIDogMTAyLjA8L2xpPjwvdWw+" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;"></iframe></div></div>`)[0];
#                 popup_ee032c2c92d399e3c1dde33f769745a7.setContent(i_frame_42707cec33db05b77e9d72adcf2d9f75);
#
#
#
#         marker_ad173c242366cfa4dcdfe44a704df69c.bindPopup(popup_ee032c2c92d399e3c1dde33f769745a7)
#         ;
#
#
#
#
#             marker_ad173c242366cfa4dcdfe44a704df69c.bindTooltip(
#                 `<div>
#                      Arcueil
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_d9a40873c212fa44a8f50bf164291396 = L.marker(
#                 [48.94785041184114, 2.2395036779070296],
#                 {}
#             ).addTo(map_c0e0a799fb5858581a013b45ef3d166e);
#
#
#         var popup_cfdf5c47aaa86af61fbdb1b93d89f707 = L.popup({"maxWidth": 300, "minWidth": 300});
#
#
#
#                 var i_frame_6d25aa25187e84d904ab1783837fbd35 = $(`<div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkFyZ2VudGV1aWw8L3N0cm9uZz48dWw+PGxpPk51bWJlciBvZiBzdGF0aW9ucyA6IDUuMDwvbGk+PGxpPlRvdGFsIENhcGFjaXR5IDogMTYxLjA8L2xpPjxsaT5CaWtlcyBBdmFpbGFibGUgOiA4My4wPC9saT48bGk+RG9ja3MgQXZhaWxhYmxlIDogNzQuMDwvbGk+PC91bD4=" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;"></iframe></div></div>`)[0];
#                 popup_cfdf5c47aaa86af61fbdb1b93d89f707.setContent(i_frame_6d25aa25187e84d904ab1783837fbd35);
#
#
#
#         marker_d9a40873c212fa44a8f50bf164291396.bindPopup(popup_cfdf5c47aaa86af61fbdb1b93d89f707)
#         ;
#
#
#
#
#             marker_d9a40873c212fa44a8f50bf164291396.bindTooltip(
#                 `<div>
#                      Argenteuil
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_e27d004582b8ee296fa879af9cd2ab25 = L.marker(
#                 [48.91578620994714, 2.2877208372591262],
#                 {}
#             ).addTo(map_c0e0a799fb5858581a013b45ef3d166e);
#
#
#         var popup_57fbf24760dfd4ff1f7656e58c509a92 = L.popup({"maxWidth": 300, "minWidth": 300});
#
#
#
#                 var i_frame_21107158731f5aa3ad507f8b0ca01725 = $(`<div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkFzbmnDqHJlcy1zdXItU2VpbmU8L3N0cm9uZz48dWw+PGxpPk51bWJlciBvZiBzdGF0aW9ucyA6IDExLjA8L2xpPjxsaT5Ub3RhbCBDYXBhY2l0eSA6IDI1NC4wPC9saT48bGk+QmlrZXMgQXZhaWxhYmxlIDogMTAxLjA8L2xpPjxsaT5Eb2NrcyBBdmFpbGFibGUgOiAxNDQuMDwvbGk+PC91bD4=" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;"></iframe></div></div>`)[0];
#                 popup_57fbf24760dfd4ff1f7656e5
